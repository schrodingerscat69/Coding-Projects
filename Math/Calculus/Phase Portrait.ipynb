# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the 2x2 matrix A
A = np.array([[-2,-1],
              [-5, 3]])

# Define the system of differential equations
def system(X, t):
    return A @ X

# Create a grid of initial conditions
x1 = np.linspace(-10, 10, 20)
x2 = np.linspace(-10, 10, 20)
X1, X2 = np.meshgrid(x1, x2)

# Compute the derivatives at each point
u = A[0, 0]*X1 + A[0, 1]*X2
v = A[1, 0]*X1 + A[1, 1]*X2

# Plotting
plt.figure(figsize=(8, 8))
plt.quiver(X1, X2, u, v, color='r')
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
plt.title('Phase Portrait')
plt.axhline(0, color='black', lw=0.5)
plt.axvline(0, color='black', lw=0.5)
plt.grid(True)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()
print(x1,x2)
# Out:
# [-10.          -8.94736842  -7.89473684  -6.84210526  -5.78947368
#   -4.73684211  -3.68421053  -2.63157895  -1.57894737  -0.52631579
#    0.52631579   1.57894737   2.63157895   3.68421053   4.73684211
#    5.78947368   6.84210526   7.89473684   8.94736842  10.        ] [-10.          -8.94736842  -7.89473684  -6.84210526  -5.78947368
#   -4.73684211  -3.68421053  -2.63157895  -1.57894737  -0.52631579
#    0.52631579   1.57894737   2.63157895   3.68421053   4.73684211
#    5.78947368   6.84210526   7.89473684   8.94736842  10.        ]
